# %% [markdown]
# <a href="https://colab.research.google.com/github/superpoupette/data/blob/main/notebooks/04_analyse_sessions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/superpoupette/data-tab.git

# %%
import os

os.chdir("/content/data-tab")

# %%
os.getcwd()
# Out:
# '/content/data-tab'

# %%
# !ls scripts
# Out:
# importation-hevy.py

# %%
import sys

sys.path.append("/content/data-tab")

from scripts.importation_hevy import (
    load_workouts,
    clean_dates,
    add_volume,
    create_sessions
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1438/1628785792.py in <cell line: 0>()
#       3 sys.path.append("/content/data-tab")
#       4
# ----> 5 from scripts.importation_hevy import (
#       6     load_workouts,
#       7     clean_dates,
#
# ModuleNotFoundError: No module named 'scripts.importation_hevy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
